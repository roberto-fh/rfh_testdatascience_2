# %% [markdown]
# ### TEST

# %%
from rfh_testdatascience_2.main import main
# Out:
# 2025-08-09 17:38:57.240 | INFO     | rfh_testdatascience_2.config:<module>:11 - PROJ_ROOT path is: C:\Users\Usuario\Desktop\Capgemini\RFH-TestDataScience-1\rfh_testdatascience_2
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# #### Caso 1: Test de lo últimos 24 meses del inputs (Grupo >=0,8M)

# %%
main(
    group='>=0.8M',
    periods=24,
    test=True
)
# Out:
# C:\Users\Usuario\Desktop\Capgemini\RFH-TestDataScience-1\rfh_testdatascience_2\rfh_testdatascience_2\model.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered_train.drop(columns='date', inplace=True)
# C:\Users\Usuario\Desktop\Capgemini\RFH-TestDataScience-1\rfh_testdatascience_2\rfh_testdatascience_2\model.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered_test.drop(columns='date', inplace=True)
# 17:38:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:38:58 - cmdstanpy - INFO - Chain [1] done processing
# ...

# %% [markdown]
# #### Caso 2: Test de lo últimos 100 meses del inputs (Grupo >=0,8M)

# %%
main(
    group='>=0.8M',
    periods=100,
    test=True
)
# Out:
# C:\Users\Usuario\Desktop\Capgemini\RFH-TestDataScience-1\rfh_testdatascience_2\rfh_testdatascience_2\model.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered_train.drop(columns='date', inplace=True)
# C:\Users\Usuario\Desktop\Capgemini\RFH-TestDataScience-1\rfh_testdatascience_2\rfh_testdatascience_2\model.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered_test.drop(columns='date', inplace=True)
# 17:38:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:38:59 - cmdstanpy - INFO - Chain [1] done processing
# MAE:  406623.04
# MSE:  225001947734.70
# RMSE: 474343.70
# ...

# %%
#### Caso 3: Test de lo últimos 24 meses del inputs (Grupo <0,8M)

# %%
main(
    group='<0.8M',
    periods=24,
    test=True
)
# Out:
# C:\Users\Usuario\Desktop\Capgemini\RFH-TestDataScience-1\rfh_testdatascience_2\rfh_testdatascience_2\model.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered_train.drop(columns='date', inplace=True)
# C:\Users\Usuario\Desktop\Capgemini\RFH-TestDataScience-1\rfh_testdatascience_2\rfh_testdatascience_2\model.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered_test.drop(columns='date', inplace=True)
# 17:38:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:38:59 - cmdstanpy - INFO - Chain [1] done processing
# MAE:  43521.95
# MSE:  2311071313.99
# RMSE: 48073.60
# ...

# %% [markdown]
# #### Caso 4: Test de lo últimos 100 meses del inputs (Grupo <0,8M)

# %%
main(
    group='<0.8M',
    periods=100,
    test=True
)
# Out:
# C:\Users\Usuario\Desktop\Capgemini\RFH-TestDataScience-1\rfh_testdatascience_2\rfh_testdatascience_2\model.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered_train.drop(columns='date', inplace=True)
# C:\Users\Usuario\Desktop\Capgemini\RFH-TestDataScience-1\rfh_testdatascience_2\rfh_testdatascience_2\model.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered_test.drop(columns='date', inplace=True)
# 17:39:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:39:00 - cmdstanpy - INFO - Chain [1] done processing
# MAE:  43169.82
# MSE:  3268741134.14
# RMSE: 57172.91
# ...

# %% [markdown]
# ### Insight
# - El modelo es muy malo, errores absolutos grandes en comparación con el nivel de la serie (~600k–900k)
# - R2 negativos representa que el modelo es peor que usar como predicción el promedio de la serie
#
# #### Posibles Causas
# - El modelo de no es apropopiado para este tipo de serie
# - Tenemos pocos datos para predicciones de 100 periodos
#
# #### Soluciones
# - Comparativas de modelos
# - Agregar estacionalidad
# - Ajustar hiperpámetros

# %% [markdown]
# ### PROD

# %% [markdown]
# #### Caso 1: Prod (Grupo >=0,8M)

# %%
main(
    group='>=0.8M',
    periods=24,
    test=False
)
# Out:
# 17:39:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:39:00 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# #### Caso 1: Prod (Grupo >=0,8M)

# %%
main(
    group='<0.8M',
    periods=24,
    test=False
)
# Out:
# 17:39:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:39:01 - cmdstanpy - INFO - Chain [1] done processing
